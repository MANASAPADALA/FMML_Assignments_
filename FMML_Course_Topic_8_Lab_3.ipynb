# %% [markdown]
# <a href="https://colab.research.google.com/github/MANASAPADALA/FMML_Assignments_/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-25 17:31:38--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   178MB/s    in 0.4s
#
# 2024-03-25 17:31:40 (178 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 14313  1802.09963v2  Many applications, including rank aggregation ...  stat
# 22263  1510.08512v1  Gaussian Graphical Models (GGMs) are popular t...  stat
# 7845   1803.07879v1  A large fraction of the electronic health reco...  stat
# 31871   1110.2098v3  Matrix factorization from a small number of ob...    cs
# 13782   1412.4210v2  We derive a synaptic weight update rule for le...    cs
# ...             ...                                                ...   ...
# 23289   1012.3951v1  Maximally stable component detection is a very...    cs
# 2408   1604.08934v2  Clustering is an underspecified task: there ar...  stat
# 16734  1705.05952v2  We present a novel neural network model that l...    cs
# 22538  1611.00555v1  Kernel dependence measures yield accurate esti...  stat
# 1811   1703.01557v2  We propose a general approach to modeling semi...    cs
#
#                                                    title  year  \
# 14313  Breaking the $1/\sqrt{n}$ Barrier: Faster Rate...  2018
# 22263  Robust Gaussian Graphical Modeling with the Tr...  2015
# 7845   An Unsupervised Multivariate Time Series Kerne...  2018
# 31871  Dynamic Matrix Factorization: A State Space Ap...  2011
# 13782  Learning Precise Spike Train to Spike Train Tr...  2014
# ...                                                  ...   ...
# 23289  Diffusion-geometric maximally stable component...  2010
# 2408   An expressive dissimilarity measure for relati...  2016
# 16734  A Novel Neural Network Model for Joint POS Tag...  2017
# 22538  Sensitivity Maps of the Hilbert-Schmidt Indepe...  2016
# 1811   Using Graphs of Classifiers to Impose Declarat...  2017
#
#                                                 keywords
# 14313  [applications, including, aggregation, bivaria...
# 22263  [graphical, structures, applications, discover...
# 7845   [electronic, measurements, collected, importan...
# 31871  [factorization, attention, ingredient, success...
# 13782  [temporally, transformations, multilayer, feed...
# ...                                                  ...
# 23289  [maximally, component, detection, computation,...
# 2408   [clustering, underspecified, universal, cluste...
# 16734  [dependency, bidirectional, representations, d...
# 22538  [dependence, estimates, nonlinear, relations, ...
# 1811   [supervised, algorithms, specifically, declara...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 14313    [applications, including, aggregation, bivaria...
# 22263    [graphical, structures, applications, discover...
# 7845     [electronic, measurements, collected, importan...
# 31871    [factorization, attention, ingredient, success...
# 13782    [temporally, transformations, multilayer, feed...
#                                ...
# 37970    [classification, significant, imbalance, subsa...
# 21841    [classification, constructed, previously, embe...
# 39118    [extraction, information, irregular, introduce...
# 22278    [identifying, objective, optimization, functio...
# 30423    [accelerating, acquisition, resonance, challen...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8831 words.
# Out of those 4575 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="75e12ed5-da62-46d3-a2e5-55c039ba384f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75e12ed5-da62-46d3-a2e5-55c039ba384f")) {                    Plotly.newPlot(                        "75e12ed5-da62-46d3-a2e5-55c039ba384f",                        [{"x":["computationally","particular","permutation","respectively","applications","permutations","estimated","aggregation","normalized","bivariate","efficiently","estimating","algorithms","statistically","narrowing","including","efficient","frobenius","observations","polynomial","graphical","theoretical","regression","simulated","guarantees","estimator","estimation","mechanism","approaches","experiments","complemented","interactions","distribution","dimensional","demonstrate","discovery","expression","statistical","structures","important","detection","baselines","techniques","represented","collected","imputation","completely","undergoing","electronic","comparable","variables","infection","naturally","unsupervised","characterized","sequences","complicate","performance","multivariate","similarities","identifying","computing","framework","measurements","information","supervised","colorectal","alleviating","classification","formulation","ingredient","preferences","dynamical","dependent","unresolved","proposals","recommendations","published","recommendation","maximization","attention","comparisons","probabilistic","measurement","expectation","structure","factorization","heuristic","principled","parameters","successful","backpropagation","innovations","perturbation","gradients","highlight","simulation","deterministic","derivation","pertaining","functional","quantities","excitatory","individual","seamlessly","leverages","temporally","multilayer","generalizing","transformations","assignment","alignment","inhibitory","intermediate","solutions","feedforward","evolutionary","algorithm","microwave","complicated","distances","establish","potential","underlying","necessary","variation","thresholding","tractable","complexity","empirical","conditional","criterion","separation","sufficient","separators","selection","introduce","nonasymptotic","conditions","propositional","limitation","diagnosis","strengths","weaknesses","inductive","developed","extracting","justification","categorized","transparency","comprehensible","artificial","extraction","respective","unsuitable","classifier","objective","optimization","following","stochastic","collection","probability","simultaneously","consequences","convexity","specified","satisfies","implements","motivated","classifiers","constraint","constrained","constraints","programming","properties","asymmetric","encourages","empirically","acquiring","relaxation","initialization","heuristics","generally","conventional","requiring","combinatorial","construct","prediction","corresponding","connections","intractable","outperforms","databases","hypothesis","presented","preliminary","scientific","evaluation","automated","constructing"],"y":[88,272,14,97,477,7,52,31,21,1,151,58,600,20,1,272,374,4,60,50,52,171,123,56,79,29,189,104,430,591,3,72,204,197,576,61,54,159,142,360,350,74,366,73,83,2,38,2,20,84,121,0,53,144,30,118,1,908,24,32,82,136,537,43,711,197,1,5,532,75,4,29,20,55,2,29,19,57,29,25,165,36,166,49,36,371,40,72,30,219,77,25,13,16,30,27,73,37,8,6,44,17,1,110,10,31,18,17,12,42,29,45,1,26,159,30,67,830,2,36,33,48,158,111,79,63,22,29,241,156,94,43,24,77,2,166,308,0,118,22,23,57,17,15,20,200,64,6,6,5,3,149,132,22,5,152,183,328,76,132,77,157,113,14,8,32,7,9,66,110,93,61,143,102,207,9,10,85,11,18,28,43,79,95,38,38,84,230,134,59,31,258,54,44,190,37,29,235,97,42],"type":"bar"},{"x":["computationally","particular","permutation","respectively","applications","permutatio ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4575,), (4575, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8025

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Feature</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.375);'>Attention</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.6581986143187067);'>Convolutional</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.6581986143187067);'>Convolutional</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>(CNNs)</span> <span style=''>have</span> <span style=''>proven</span> <span style='background-color:rgba(0, 255, 0, 0.3691931540342297);'>effective</span> <span style=''>for</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.4371859296482411);'>processing</span> <span style=''>tasks</span> <span style=''>such</span> <span style=''>as</span> <span style=''>object</span> <span style='background-color:rgba(0, 255, 0, 0.6412371134020618);'>recognition</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>Recently</span> <span style=''>CNNs</span> <span style=''>have</span> <span style=''>been</span> <span style=''>enhanced</span> <span style=''>with</span> <span style=''>concepts</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.375);'>attention</span> <span style=''>similar</span> <span style=''>to</span> <span style=''>those</span> <span style=''>found</span> <span style=''>in</span> <span style=''>biology</span> <span style=''>Much</span> <span style=''>of</span> <span style=''>this</span> <span style=''>work</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.375);'>attention</span> <span style=''>has</span> <span style=''>focused</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3691931540342297);'>effective</span> <span style=''>serial</span> <span style=''>spatial</span> <span style='background-color:rgba(0, 255, 0, 0.4371859296482411);'>processing</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>I</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>simple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>for</span> <span style=''>applying</span> <span style=''>feature</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.375);'>attention</span> <span style=''>(FBA)</span> <span style=''>to</span> <span style=''>CNNs</span> <span style=''>and</span> <span style=''>compare</span> <span style=''>multiple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implementation</span> <span style=''>options</span> <span style=''>FBA</span> <span style=''>is</span> <span style=''>a</span> <span style=''>top</span> <span style=''>down</span> <span style=''>signal</span> <span style=''>applied</span> <span style=''>globally</span> <span style=''>to</span> <span style=''>an</span> <span style=''>input</span> <span style=''>image</span> <span style=''>which</span> <span style=''>aides</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.4642857142857143);'>detecting</span> <span style=''>chosen</span> <span style=''>objects</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>cluttered</span> <span style=''>or</span> <span style=''>noisy</span> <span style=''>settings</span> <span style=''>The</span> <span style=''>concept</span> <span style=''>of</span> <span style=''>FBA</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implementation</span> <span style=''>details</span> <span style=''>tested</span> <span style=''>here</span> <span style=''>were</span> <span style=''>derived</span> <span style=''>from</span> <span style=''>what</span> <span style=''>is</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style=''>Dropout</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Sparsifies</span> <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>We</span> <span style=''>explore</span> <span style=''>a</span> <span style=''>recently</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style=''>Dropout</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>that</span> <span style=''>provided</span> <span style=''>an</span> <span style=''>elegant</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretation</span> <span style=''>to</span> <span style=''>Gaussian</span> <span style=''>Dropout</span> <span style=''>We</span> <span style=''>extend</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style=''>Dropout</span> <span style=''>to</span> <span style=''>the</span> <span style=''>case</span> <span style=''>when</span> <span style=''>dropout</span> <span style=''>rates</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unbounded</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>way</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>variance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>gradient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>and</span> <span style=''>report</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimental</span> <span style=''>results</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>dropout</span> <span style=''>rates</span> <span style=''>per</span> <span style=''>weight</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Interestingly</span> <span style=''>it</span> <span style=''>leads</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extremely</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>solutions</span> <span style=''>both</span> <span style=''>in</span> <span style=''>fully</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connected</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>layers</span> <span style=''>This</span> <span style=''>effect</span> <span style=''>is</span> <span style=''>similar</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relevance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determination</span> <span style=''>effect</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>Bayes</span> <span style=''>but</span> <span style=''>has</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>advantages</span> <span style=''>We</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>up</span> <span style=''>to</span> <span style=''>280</span> <span style=''>times</span> <span style=''>on</span> <span style=''>LeNet</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style=''>and</span> <span style=''>up</span> <span style=''>to</span> <span style=''>68</span> <span style=''>times</span> <span style=''>on</span> <span style=''>VGG</span> <span style=''>like</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Scaling</span> <span style=''>Limit</span> <span style=''>Exact</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Tractable</span> <span style=''>Analysis</span> <span style=''>of</span> <span style=''>Online</span> <span style=''>Learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Applications</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.39568345323741005);'>Regularized</span> <span style='background-color:rgba(255, 0, 0, 0.4979591836734695);'>Regression</span> <span style=''>and</span> <span style=''>PCA</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analyzing</span> <span style=''>the</span> <span style=''>exact</span> <span style=''>dynamics</span> <span style=''>of</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style=''>online</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>in</span> <span style=''>the</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.317157712305026);'>dimensional</span> <span style=''>scaling</span> <span style=''>limit</span> <span style=''>Our</span> <span style=''>results</span> <span style=''>are</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>two</span> <span style=''>concrete</span> <span style=''>examples</span> <span style=''>online</span> <span style='background-color:rgba(255, 0, 0, 0.39568345323741005);'>regularized</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.4979591836734695);'>regression</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>analysis</span> <span style=''>As</span> <span style=''>the</span> <span style=''>ambient</span> <span style='background-color:rgba(255, 0, 0, 0.4228855721393035);'>dimension</span> <span style=''>tends</span> <span style=''>to</span> <span style=''>infinity</span> <span style=''>and</span> <span style=''>with</span> <span style=''>proper</span> <span style=''>time</span> <span style=''>scaling</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>time</span> <span style=''>varying</span> <span style=''>joint</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>measures</span> <span style=''>of</span> <span style=''>the</span> <span style=''>target</span> <span style=''>feature</span> <span style=''>vector</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimates</span> <span style=''>provided</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>will</span> <span style=''>converge</span> <span style=''>weakly</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>deterministic</span> <span style=''>measured</span> <span style=''>valued</span> <span style=''>process</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterized</span> <span style=''>as</span> <span style=''>the</span> <span style=''>unique</span> <span style=''>solution</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.313953488372093);'>nonlinear</span> <span style=''>PDE</span> <span style='ba ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Sparse</span> <span style=''>and</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>of</span> <span style=''>large</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>symmetric</span> <span style=''>matrices</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>biharmonic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpolation</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Symmetric</span> <span style=''>matrices</span> <span style=''>are</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>such</span> <span style=''>as</span> <span style=''>kernel</span> <span style=''>machines</span> <span style=''>and</span> <span style=''>manifold</span> <span style=''>learning</span> <span style=''>Using</span> <span style=''>large</span> <span style=''>datasets</span> <span style=''>often</span> <span style=''>requires</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computing</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>symmetric</span> <span style=''>matrices</span> <span style=''>so</span> <span style=''>that</span> <span style=''>they</span> <span style=''>fit</span> <span style=''>in</span> <span style=''>memory</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>method</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>biharmonic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpolation</span> <span style=''>for</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>The</span> <span style=''>method</span> <span style=''>exploits</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>manifold</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpolation</span> <span style=''>operator</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximates</span> <span style=''>values</span> <span style=''>using</span> <span style=''>a</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>randomly</span> <span style=''>selected</span> <span style=''>landmark</span> <span style=''>points</span> <span style=''>This</span> <span style=''>operator</span> <span style=''>is</span> <span style=''>readily</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sparsified</span> <span style=''>reducing</span> <span style=''>memory</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>requirements</span> <span style=''>by</span> <span style=''>at</span> <span style=''>least</span> <span style=''>two</span> <span style=''>orders</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>magnitude</span> <span style=''>without</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>loss</span> <span style=''>in</span> <span style=''>accuracy</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>our</span> <span style=''>method</span> <span style=''>can</span> <span style='background-color:rg ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10174315190323728)
# 	experimental (0.1344717182497332)
# 	challenging (0.09640697260761295)
# 	architecture (0.08360014229811455)
# 	segmentation (0.07150480256136606)
# 	information (0.2529348986125934)
# 	different (0.2550693703308431)
# 	detection (0.12451085023123444)
# 	convolutional (0.12771255780860905)
# 	recognition (0.1415866239772323)
#
# Some Statistics words are:
# 	distributions (0.12267471091000502)
# 	statistical (0.14881850175967823)
# 	theoretical (0.15434891905480141)
# 	variables (0.13826043237807945)
# 	stochastic (0.14228255404725992)
# 	estimation (0.17194570135746606)
# 	inference (0.20261437908496732)
# 	dimensional (0.1910507792860734)
# 	distribution (0.19658119658119658)
# 	regression (0.1845148315736551)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="59725a1f-26d3-446b-b1b9-e0008aff840f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59725a1f-26d3-446b-b1b9-e0008aff840f")) {                    Plotly.newPlot(                        "59725a1f-26d3-446b-b1b9-e0008aff840f",                        [{"x":["computationally","particular","permutation","respectively","applications","permutations","estimated","aggregation","normalized","bivariate","efficiently","estimating","algorithms","statistically","narrowing","including","efficient","frobenius","observations","polynomial","graphical","theoretical","regression","simulated","guarantees","estimator","estimation","mechanism","approaches","experiments","complemented","interactions","distribution","dimensional","demonstrate","discovery","expression","statistical","structures","important","detection","baselines","techniques","represented","collected","imputation","completely","undergoing","electronic","comparable","variables","infection","naturally","unsupervised","characterized","sequences","complicate","performance","multivariate","similarities","identifying","computing","framework","measurements","information","supervised","colorectal","alleviating","classification","formulation","ingredient","preferences","dynamical","dependent","unresolved","proposals","recommendations","published","recommendation","maximization","attention","comparisons","probabilistic","measurement","expectation","structure","factorization","heuristic","principled","parameters","successful","backpropagation","innovations","perturbation","gradients","highlight","simulation","deterministic","derivation","pertaining","functional","quantities","excitatory","individual","seamlessly","leverages","temporally","multilayer","generalizing","transformations","assignment","alignment","inhibitory","intermediate","solutions","feedforward","evolutionary","algorithm","microwave","complicated","distances","establish","potential","underlying","necessary","variation","thresholding","tractable","complexity","empirical","conditional","criterion","separation","sufficient","separators","selection","introduce","nonasymptotic","conditions","propositional","limitation","diagnosis","strengths","weaknesses","inductive","developed","extracting","justification","categorized","transparency","comprehensible","artificial","extraction","respective","unsuitable","classifier","objective","optimization","following","stochastic","collection","probability","simultaneously","consequences","convexity","specified","satisfies","implements","motivated","classifiers","constraint","constrained","constraints","programming","properties","asymmetric","encourages","empirically","acquiring","relaxation","initialization","heuristics","generally","conventional","requiring","combinatorial","construct","prediction","corresponding","connections","intractable","outperforms","databases","hypothesis","presented","preliminary","scientific","evaluation","automated","constructing","construction","overfitting","different","performances","formations","abilities","surprisingly","intriguing","connectivity","architecture","experimental","exploration","feasibility","represent","utilization","operational","improvement","popularity","performing","predicted","achieving","formation","interestingly","abstractions","regularization","accelerate","discovered","directions","separable","adaptations","computational","reconstruct","dictionary","challenge","estimates","acceleration","dictionaries","measuring","representations","reconstruction","therefore","significantly","fundamental","popularly","diffusion","resolution","exploiting","separability","representation","compressed","orientation","frameworks","efficiency","evaluating", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	infection
# 	nonasymptotic
# 	interventional
# 	emphdirectly
# 	positivity
# 	triggering
# 	unsuccessful
# 	exponents
# 	subsample
# 	causation
# 	layerwise
# 	modulating
# 	tournament
# 	pseudolikelihood
# 	asymptotics
# 	multipartite
# 	explanatory
# 	volatility
# 	stabilizing
# 	concordance
# Some words which never appear in Statistics papers:
# 	propositional
# 	formations
# 	disjunctive
# 	compilation
# 	attentive
# 	thereafter
# 	hallucination
# 	animation
# 	illuminations
# 	occlusions
# 	productions
# 	formalisms
# 	elaborated
# 	cartesian
# 	articulated
# 	discourse
# 	disambiguation
# 	resourced
# 	transliteration
# 	complementing

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.059507419305492e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7575
